# %% [markdown]
# Movie Ticket Booking System

# %%
movie_dates = {
    "Dhurandhar": "2025-12-05",
    "Zootopia 2": "2025-11-28",
    "Avtar:Fire & Ash": "2025-12-19",
    "Tere Ishq Mein": "2025-11-28",
    "Kis Kisko Pyaar Karoon 2": "2025-12-12",
    "Ikkis":"2026-01-01",
    "The Housemaid":"2026-01-02",
    "Border-2":"2026-01-23",
    "28 Years Later:The Bone Temple":"2026-01-16"
    
}

movie_prices = {
    "Dhurandhar": 350.0,                     
    "Zootopia 2": 300.0,                     
    "Avtar:Fire & Ash": 300.0,               
    "Tere Ishq Mein": 200.0,                 
    "Kis Kisko Pyaar Karoon 2": 200.0,     
    "Ikkis": 230.0,                        
    "The Housemaid": 200.0,                 
    "Border-2": 320.0,                      
    "28 Years Later:The Bone Temple": 300.0  
}


print("\nAvailable Movies:", list(movie_dates.keys()))

movie = input("\nEnter the movie you want to watch:")

if movie in movie_dates:
    print("Movie found in box-office list.")
    print("Release date:", movie_dates[movie])
else:
    print("Movie is no longer available in box-office.")

date = input("\nEnter the date you want to watch this movie(yyyy-mm-dd):")

if date>= movie_dates[movie]:
    print("Your booking process is underway")
else:
    print("You are too early for the movie, wait till it gets released")


seats = int(input("\nHow many seats do you want to book (max 10)? "))

if seats<10 and seats<=0:
    print("Sorry! You can book only max-10 tickets and min-1 ticket")
else:
    print("Select your ticket:")
    for i in range(10):
        print(" 🟦 "*6)

total= seats * movie_prices[movie]
promo = input("\nAny promo code? (yes/no): ")
if promo == "yes"or promo == "YES":
    code = input("Enter promo code: ")
    
    if code == "FIRSTMOVIE":
        total = total - total/2
    elif code == "SAVE10":
        total = total - (total * 0.10)
    elif code == "BEGIN2026":
        total = total - (total * 0.25)
    else:
        print("Invalid code, no discount applied.")

elif promo == "no"or promo == "NO":
    print("No promo code applied.")

else:
    print("Invalid choice. Continuing without promo.")

print("\n--- TICKET CONFIRMED ---")
print("Movie:", movie)
print("Seats:", seats)
print("Final Amount:", total)
print("------------------------")
# Out:
# Available Movies: ['Dhurandhar', 'Zootopia 2', 'Avtar:Fire & Ash', 'Tere Ishq Mein', 'Kis Kisko Pyaar Karoon 2', 'Ikkis', 'The Housemaid', 'Border-2', '28 Years Later:The Bone Temple']
# Enter the movie you want to watch: Dhurandhar
# Movie found in box-office list.
# Release date: 2025-12-05
# Enter the date you want to watch this movie(yyyy-mm-dd): 2025-12-27
# Your booking process is underway
# How many seats do you want to book (max 10)?  5
# Select your ticket:
#  🟦  🟦  🟦  🟦  🟦  🟦
#  🟦  🟦  🟦  🟦  🟦  🟦
#  🟦  🟦  🟦  🟦  🟦  🟦
#  🟦  🟦  🟦  🟦  🟦  🟦
#  🟦  🟦  🟦  🟦  🟦  🟦
#  🟦  🟦  🟦  🟦  🟦  🟦
#  🟦  🟦  🟦  🟦  🟦  🟦
#  🟦  🟦  🟦  🟦  🟦  🟦
#  🟦  🟦  🟦  🟦  🟦  🟦
#  🟦  🟦  🟦  🟦  🟦  🟦
# Any promo code? (yes/no):  YES
# Enter promo code:  BEGIN2026
# --- TICKET CONFIRMED ---
# Movie: Dhurandhar
# Seats: 5
# Final Amount: 1312.5
# ------------------------

# %%
print(movie_dates)
# Out:
# {'Dhurandhar': '2025-12-05', 'Zootopia 2': '2025-11-28', 'Avtar:Fire & Ash': '2025-12-19', 'Tere Ishq Mein': '2025-11-28', 'Kis Kisko Pyaar Karoon 2': '2025-12-12', 'Ikkis': '2026-01-01', 'The Housemaid': '2026-01-02', 'Border-2': '2026-01-23', '28 Years Later:The Bone Temple': '2026-01-16'}

# %%
print(movie_prices)
# Out:
# {'Dhurandhar': 350.0, 'Zootopia 2': 300.0, 'Avtar:Fire & Ash': 300.0, 'Tere Ishq Mein': 200.0, 'Kis Kisko Pyaar Karoon 2': 200.0, 'Ikkis': 230.0, 'The Housemaid': 200.0, 'Border-2': 320.0, '28 Years Later:The Bone Temple': 300.0}
